# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,random_state=0,test_size=1/3)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_
print("The R_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# The R_score valueforbestparameter{'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_pred,y_test)

# %%
r_score
print("The R_score valueforbestparameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score valueforbestparameter{'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}: 0.6574911175621592

# %%
table=pd.DataFrame.from_dict(result) 
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010198      0.000151         0.004069        0.004984
# 1        0.004036      0.004943         0.004139        0.005072
# 2        0.010220      0.000253         0.004164        0.005104
# 3        0.004949      0.004638         0.004665        0.005102
# 4        0.006799      0.005559         0.004736        0.005801
# 5        0.006067      0.004954         0.004041        0.004949
# 6        0.012155      0.004052         0.005637        0.004631
# 7        0.008521      0.004207         0.002952        0.002611
# 8        0.023541      0.003756         0.004522        0.002046
# 9        0.018931      0.004895         0.002809        0.003493
# 10       0.025687      0.004738         0.003638        0.003221
# 11       0.019055      0.003504         0.004486        0.003800
# 12       0.010504      0.002955         0.003807        0.002522
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_prediction
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[39983.42595]
# C:\Users\LENOVO\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
