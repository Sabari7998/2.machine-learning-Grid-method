# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,random_state=0,test_size=1/3)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2'], 'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
result=grid.cv_results_
print("The R_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# The R_score valueforbestparameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}:

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_pred,y_test)

# %%
r_score
print("The R_score valueforbestparameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score valueforbestparameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8457904563303404

# %%
table=pd.DataFrame.from_dict(result) 
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.052662      0.004550         0.006050        0.004940
# 1        0.429591      0.006724         0.016145        0.004963
# 2        0.044838      0.004871         0.006035        0.004928
# 3        0.427626      0.010096         0.014341        0.005258
# 4        0.049142      0.002591         0.003379        0.004266
# 5        0.425151      0.004166         0.014100        0.004944
# 6        0.046317      0.004940         0.004026        0.004930
# 7        0.426043      0.008634         0.016103        0.004926
# 8        0.103164      0.003940         0.008059        0.004030
# 9        1.151860      0.060315         0.016111        0.004932
# 10       0.100669      0.000014         0.010072        0.000016
# 11       1.044377      0.015346         0.013074        0.004486
# 12       0.048062      0.003925         0.008093        0.004064
# 13       0.453434      0.004786         0.020217        0.000121
# 14       0.046884      0.004907         0.006047        0.004937
# 15       0.426947      0.052271         0.018142        0.004014
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4     friedman_mse               sqrt                 10
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 10
# 7     friedman_mse               log2                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12         poisson               sqrt                 10
# 13         poisson               sqrt                100
# 14         poisson               log2                 10
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.744564
# 1   {'criterion': 'squared_error', 'max_features':...           0.807892
# 2   {'criterion': 'squared_error', 'max_features':...           0.767640
# 3   {'criterion': 'squared_error', 'max_features':...           0.803417
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.797045
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.807761
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.766186
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.811466
# 8   {'criterion': 'absolute_error', 'max_features'...           0.789072
# 9   {'criterion': 'absolute_error', 'max_features'...           0.802081
# 10  {'criterion': 'absolute_error', 'max_features'...           0.799102
# 11  {'criterion': 'absolute_error', 'max_features'...           0.798638
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.815549
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.806841
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.801073
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.802925
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.750314           0.803235           0.813177
# 1            0.773759           0.836341           0.831262
# 2            0.711539           0.821557           0.792893
# 3            0.767347           0.836755           0.835266
# 4            0.752081           0.825227           0.811080
# 5            0.763991           0.837488           0.831556
# 6            0.743481           0.817111           0.783091
# 7            0.772429           0.836899           0.829782
# 8            0.754814           0.815053           0.813245
# 9            0.768935           0.840275           0.828025
# 10           0.723940           0.831406           0.813272
# 11           0.771698           0.841877           0.829350
# 12           0.748720           0.798593           0.812933
# 13           0.774410           0.834708           0.830636
# 14           0.751018           0.804921           0.829971
# 15           0.774091           0.830438           0.834439
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.740655         0.770389        0.031189               14
# 1            0.759240         0.801699        0.030646                2
# 2            0.756242         0.769974        0.036864               16
# 3            0.764846         0.801526        0.031294                3
# 4            0.739366         0.784960        0.033495               10
# 5            0.759537         0.800067        0.032849                7
# 6            0.740871         0.770148        0.028132               15
# 7            0.761550         0.802425        0.030296                1
# 8            0.744105         0.783258        0.029278               11
# 9            0.758822         0.799628        0.031849                8
# 10           0.744890         0.782522        0.041129               12
# 11           0.763399         0.800992        0.030831                5
# 12           0.734686         0.782096        0.033775               13
# 13           0.760447         0.801408        0.029663                4
# 14           0.756473         0.788691        0.030259                9
# 15           0.760104         0.800400        0.029608                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
Future_prediction
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[43656.3654042]
# C:\Users\LENOVO\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
